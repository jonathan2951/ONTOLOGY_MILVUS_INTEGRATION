# %%
import os
import json
import pandas as pd
import numpy as np
import time

from dotenv import load_dotenv
load_dotenv()

#openai embeddings
from openai import OpenAI
openai_client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
def retrieve_data_dict_json(directory_path: str, files_to_match: list[str]) -> dict[str, list]:
    """_summary_

    Args:
        directory_path (str): _description_
        files_to_match (list[str]): _description_

    Returns:
        dict: _description_
    """
    inputs = []
    names = []
    for filename in os.listdir(directory_path):
        full_path = os.path.join(directory_path, filename)
        if os.path.isfile(full_path):
            if len(files_to_match) > 0:
                if filename in files_to_match:
                    with open(full_path) as f:
                        inputs.append(json.load(f))
                        names.append(full_path.replace(directory_path, ""))
            else:
                with open(full_path) as f:
                    inputs.append(json.load(f))
                    names.append(full_path.replace(directory_path, ""))

    return {"data": inputs, "names": names}

# %%
#all data dicts
data_dictionaries = retrieve_data_dict_json(
    directory_path="/Users/jonathan/Documents/WORK/NEO4J-TESTS/data_dicts_v4/tenants/group_iii/silver/data_dict", 
    files_to_match=[])

# %%
# add categories_mapping
df = pd.read_csv("./categories_mapping.csv")

# %%
def make_context(inputs: list[dict]) -> list[str]:
    """parse data dictionaries and prepare context for query
    """
    res = []
    for datadict in inputs:
        # search consolidated category
        try:
            category = df[df["table_name"] == datadict['table']]['consolidated_category'].values[0]
        except:
            print(f"mapping category not found for {datadict['table']}")
            category = "None"
        ctx = ""
        table_name = f"{datadict['catalog']}.{datadict['schema']}.{datadict['table']}"
        table_description = '.'.join(datadict["description"].split(".")[1:])
        table_analysis = f"{",".join([x for x in datadict['table_analysis']])}" # not used
        table_primary_keys = ",".join([x for x in datadict["primary_key"]])

        ctx = f"table name:{table_name}\n"
        ctx += f"table description: {table_description}\n"
        ctx += f"table_primary_keys:{table_primary_keys}\n"
        cols = ",".join([x.get('column_name') for x in datadict.get("columns") if "__hevo__" not in x.get('column_name')]) # filter hevo tables
        ctx += f"columns available:{cols}\n"
        ctx += f"category: {category}"
        res.append(ctx)
    return res

# %%
data_to_embed = make_context(inputs=data_dictionaries['data'])
# Out:
# mapping category not found for group_iii_2023_and_2024_sales_xlsx_2023_cleaned

# %%
# example
print(data_to_embed[0])
# Out:
# table name:group_iii.silver.group_iii_purchase_xlsx_g_3_p_order
# table description:  It covers data from various dates and contains information about purchase orders, including details such as order number, date, vendor, status, and quantities. This data is valuable for tracking purchase orders, analyzing vendor performance, and managing inventory levels.
# table_primary_keys:OrderNbr,LineNbr
# columns available:Type,OrderNbr,Date,PromisedOn,Vendor,VendorName,Status,TotalOrderQty,OpenQuantity,CreatedBy,InventoryID,Description,Description_2,ShipTo,AccountName,OrderQty_2,QtyOnReceipts,ExtCost,UnitCost,LineNbr,BranchID,EntityType
# category: Procurement & Inventory

# %%
# get table names ; used later when inserting the data into collection
# table_name is needed as a searchable field 
tables_names = [f"{x['catalog']}.{x['schema']}.{x['table']}" for x in data_dictionaries['data']]

# %%
# get categories; used later when inserting the data into collection
# category is needed as a searchable field 
categories= []
for x in tables_names:
    name = x.replace("group_iii.silver.","")
    try:
        category = df[df["table_name"] == name]['consolidated_category'].values[0]
    except:
        print(f"mapping category not found for {x}")
        category = "None"
    categories.append(category)
# Out:
# mapping category not found for group_iii.silver.group_iii_2023_and_2024_sales_xlsx_2023_cleaned

# %%
from pymilvus import MilvusClient
from pymilvus import FieldSchema, CollectionSchema, DataType, Collection

# create a client
# client = MilvusClient(uri="http://localhost:19530")

# create a client on production
client = MilvusClient(uri="http://localhost:8000", db_name="ontology")

try:
    collections = client.list_collections()
    print(f"Successfully connected to Milvus. Collections: {collections}")
except Exception as e:
    print(f"Failed to connect to Milvus or retrieve collections: {e}")
# Out:
# Successfully connected to Milvus. Collections: ['group_iii_data_dicts_table_20251104', 'group_iii_data_dicts_table', 'group_iii_data_dicts_column', 'ontology_tables', 'ontology_columns', 'group_iii_data_dicts_column_20251104', 'test_collection']

# %%
def get_embedding(text: str, model: str="text-embedding-3-large"):
    resp = openai_client.embeddings.create(
        model=model,
        input=text
    )
    # The actual output structure depends on version; example:
    return resp.data[0].embedding

# %%
# all the table content will be embedded 
embeddings = [get_embedding(data) for data in data_to_embed]

# %%
# Create schema
schema = client.create_schema(
    enable_dynamic_field=True,
    auto_id=True
)

fields = [
    FieldSchema(
        name="id", 
        dtype=DataType.INT64, 
        description="a unique ID",
        is_primary=True, 
        auto_id=False
    ),
    FieldSchema(
        name="vector", 
        description="the embedding vector",
        dtype=DataType.FLOAT_VECTOR, 
        dim=3072
    ),
    FieldSchema(
        name="text", 
        description="the content of the vector embedding",
        dtype=DataType.VARCHAR, 
        max_length=8192, 
        enable_analyzer=True, # Enables text analysis (tokenization)
        enable_match=True # Enables inverted indexing for phrase matching)
    ),
    FieldSchema(
        name="name", 
        description="the name of the column",
        dtype=DataType.VARCHAR, 
        max_length=8192, 
        enable_analyzer=True, # Enables text analysis (tokenization)
        enable_match=True # Enables inverted indexing for phrase matching)
    ),
    FieldSchema(
        name="category", 
        description="the category mapped to this table",
        dtype=DataType.VARCHAR, 
        max_length=8192, 
        enable_analyzer=True, # Enables text analysis (tokenization)
        enable_match=True # Enables inverted indexing for phrase matching)
    )
]

schema = CollectionSchema(
    fields,
    description="(tesintg only) tables informations including name, description, columns available and primary keys. query enabled"
)

# Create collection
collection_name = "testing_group_iii_data_dicts_table_20251104"

# Create an index file
client.create_collection(
    collection_name=collection_name,
    schema=schema, 
)

# %%
# Set up the index parameters
index_params = client.prepare_index_params()

# Add an index on the vector field.
index_params.add_index(
    field_name="vector",
    metric_type="COSINE",
    index_type="IVF_FLAT",
    index_name="vector_index",
    params={ "nlist": 128 }
)

# Create an index file
client.create_index(
    collection_name=collection_name,
    index_params=index_params,
    sync=True # Whether to wait for index creation to complete before returning. Defaults to True.
)

# %%
# inserting data
data_to_collection = [
    {
        "id": i,
        "name": tables_names[i],
        "vector": embeddings[i], 
        "text": data_to_embed[i], 
        "category": categories[i]
    }
    for i in range(len(data_to_embed))
]

print("Data has", len(data_to_collection), "entities, each with fields: ", data_to_collection[0].keys())
print("Vector dim:", len(data_to_collection[0]["vector"]))
# Out:
# Data has 760 entities, each with fields:  dict_keys(['id', 'name', 'vector', 'text', 'category'])
# Vector dim: 3072

# %%
res = client.insert(
    collection_name=collection_name,
    data=data_to_collection
)

# %%
# After final entity is inserted, it is best to call flush to have no growing segments left in memory
# https://milvus.io/api-reference/pymilvus/v2.2.x/MilvusClient/Collection/flush().md
client.flush(collection_name=collection_name)

# load the collection to make it available
client.load_collection(collection_name=collection_name)

# %%
# semantic matching vector embedding

def embed_text(texts, model="text-embedding-3-large"):
    """
    Convert raw text into embedding vectors using OpenAI embeddings.
    """
    if isinstance(texts, str):
        texts = [texts]  # Convert single string to list for consistency

    response = openai_client.embeddings.create(
        input=texts,
        model=model
    )
    return [item.embedding for item in response.data]


query: str = "stock_iq"
query_vector = embed_text(texts=query)

search_params = {
    "metric_type": "COSINE",
    "params": {"nprobe": 128}
}
top_k = 5


# Single vector search
res = client.search(
    collection_name=collection_name,
    data=query_vector,
    search_params=search_params,
    limit=top_k,
    output_fields=["text", "name"]
)

# %%
for i, hits in enumerate(res):
    for hit in hits:
        print(f"name:{hit.entity.get('name')}")
        print(f"distance: {hit.get('distance')}")
        print("")
# Out:
# name:group_iii.silver.stock_iq_forecast_2024_2025_xlsx_sheet
# distance: 0.5004482865333557
#
# name:group_iii.silver.stock_iq_lost_sales_xlsx_sheet
# distance: 0.42270272970199585
#
# name:group_iii.silver.insitestatus
# distance: 0.3762144446372986
#
# name:group_iii.silver.initemstats
# distance: 0.372540146112442
#
# name:group_iii.silver.inturnovercalcitem
# distance: 0.367465615272522

# %%
# direct filtering
# https://milvus.io/docs/boolean.md
filter = "name == 'group_iii.silver.initemstats'"
res2 = client.query(
    collection_name=collection_name,
    filter=filter,
    output_fields=["text", "name", "id"],
)

# %%
# here we see that only 1 document has been retrieved since it is an exact match
res2, len(res2)
# Out:
# (data: ["{'id': 278, 'text': 'table name:group_iii.silver.initemstats\\ntable description:  It covers data from the years 2023 to 2025. The table contains information about inventory items, including details such as CompanyID, InventoryID, SiteID, and various cost metrics. This data is valuable for tracking inventory levels, costs, and site-specific information, aiding in inventory management and financial analysis.\\ntable_primary_keys:CompanyID,InventoryID,SiteID\\ncolumns available:CompanyID,InventoryID,SiteID,QtyOnHand,TotalCost,MinCost,MaxCost,LastCost,LastCostDate,LastPurchaseDate,ValMethod,tstamp\\ncategory: Procurement & Inventory', 'name': 'group_iii.silver.initemstats'}"], extra_info: {},
#  1)

# %%
# when filtering on categories, because 1 category contains many tables, we got several records
filter = "category == 'Procurement & Inventory'"
res3 = client.query(
    collection_name=collection_name,
    filter=filter,
    output_fields=["name", "id", "category"],
)

[x for x in res3]
# Out:
# [{'name': 'group_iii.silver.group_iii_purchase_xlsx_g_3_p_order',
#   'id': 0,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemsitehistday',
#   'id': 1,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.incategory',
#   'id': 7,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poreceipt',
#   'id': 13,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemcustsalesstats',
#   'id': 19,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqsetupapproval',
#   'id': 46,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.insetup',
#   'id': 51,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemclass',
#   'id': 52,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemcost',
#   'id': 58,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inplantype',
#   'id': 61,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.wmsjob',
#   'id': 66,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.intrancost',
#   'id': 73,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poline',
#   'id': 76,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.insubitem',
#   'id': 104,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.portalmap',
#   'id': 110,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inabccode',
#   'id': 117,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.state',
#   'id': 118,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inrelatedinventory',
#   'id': 131,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poreceiptline',
#   'id': 145,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inpiclasslocation',
#   'id': 147,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poaccrualdetail',
#   'id': 158,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.incoststatus',
#   'id': 164,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inregister',
#   'id': 180,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.posetup',
#   'id': 186,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.pocontact',
#   'id': 190,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inlocationstatus',
#   'id': 192,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inreplenishmentorder',
#   'id': 199,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.shiptermsdetail',
#   'id': 201,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.insitestatus',
#   'id': 209,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqsetup',
#   'id': 210,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poreceiveputawaysetup',
#   'id': 223,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.location',
#   'id': 225,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.vendor',
#   'id': 230,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inreplenishmentpolicy',
#   'id': 240,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.instance',
#   'id': 257,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.insite',
#   'id': 267,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqrequisitionorder',
#   'id': 270,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemsite',
#   'id': 273,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemstats',
#   'id': 278,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemclassrep',
#   'id': 282,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inpiheader',
#   'id': 289,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inreplenishmentclass',
#   'id': 297,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.povendorinventory',
#   'id': 307,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.vendorclass',
#   'id': 314,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inlocationstatusbycostcenter',
#   'id': 319,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemplan',
#   'id': 331,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemsitehistbycostcenterd',
#   'id': 334,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poaccrualsplit',
#   'id': 336,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inreceiptstatus',
#   'id': 347,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inscanusersetup',
#   'id': 352,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inreplenishmentline',
#   'id': 361,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inpidetail',
#   'id': 364,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqrequestline',
#   'id': 366,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poaddress',
#   'id': 374,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poorderreceipt',
#   'id': 385,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.polandedcostdoc',
#   'id': 386,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.shipterms',
#   'id': 393,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inlotserclass',
#   'id': 416,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemrep',
#   'id': 421,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inunit',
#   'id': 429,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.insitebuilding',
#   'id': 440,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqbidding',
#   'id': 448,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poreceiveputawayusersetup',
#   'id': 449,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inturnovercalcitem',
#   'id': 452,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqrequestclass',
#   'id': 456,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.intote',
#   'id': 461,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemsaleshist',
#   'id': 477,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.polandedcostsplit',
#   'id': 478,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.incostsite',
#   'id': 488,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.polinebillingrevision',
#   'id': 489,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.insitestatusbycostcenter',
#   'id': 495,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.intransplit',
#   'id': 508,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inturnovercalc',
#   'id': 515,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.fobpoint',
#   'id': 525,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemcosthist',
#   'id': 535,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inventory_asin_sourcing_retail_united_states_todate_1_1_2025_4_6_2025',
#   'id': 538,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqrequest',
#   'id': 539,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inventoryitemcurysettings',
#   'id': 542,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemxref',
#   'id': 543,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inscansetup',
#   'id': 549,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemsitehist',
#   'id': 554,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.polandedcostreceipt',
#   'id': 571,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inpiclassitem',
#   'id': 575,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initembox',
#   'id': 578,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inventory_asin_sourcing_retail_united_states_yearly_1_1_2023_12_31_2023',
#   'id': 580,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqrequisition',
#   'id': 582,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poreceiptlinesplit',
#   'id': 594,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inpostclass',
#   'id': 597,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inpiclass',
#   'id': 598,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.polandedcostdetail',
#   'id': 608,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqrequisitioncontent',
#   'id': 612,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inavailabilityscheme',
#   'id': 628,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.polandedcostreceiptline',
#   'id': 635,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemclasscurysettings',
#   'id': 641,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemsitehistd',
#   'id': 653,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemcustsaleshist',
#   'id': 660,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqbiddingvendor',
#   'id': 665,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.intransitline',
#   'id': 668,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.rqrequisitionline',
#   'id': 674,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.initemsaleshistd',
#   'id': 677,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inkitspechdr',
#   'id': 679,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inlocation',
#   'id': 681,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poaccrualstatus',
#   'id': 684,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inventory_asin_sourcing_retail_united_states_yearly_1_1_2024_12_31_2024',
#   'id': 699,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.inkitspecstkdet',
#   'id': 708,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.intran',
#   'id': 728,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.poorder',
#   'id': 733,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.landedcostcode',
#   'id': 736,
#   'category': 'Procurement & Inventory'},
#  {'name': 'group_iii.silver.incostsubitemxref',
#   'id': 746,
#   'category': 'Procurement & Inventory'}]

# %%
# partial filtering, SQL like expression
# https://milvus.io/docs/boolean.md
filter_expression = "name like \"%initem%\" " 

res4 = client.query(
    collection_name=collection_name,
    filter=filter_expression,
    output_fields=["text", "name", "id", "category"],
)

for x in res4:
    print(f"{x.get("name")}", {x.get("category")})
# Out:
# group_iii.silver.initemsitehistday {'Procurement & Inventory'}
# group_iii.silver.initemcustsalesstats {'Procurement & Inventory'}
# group_iii.silver.initemclass {'Procurement & Inventory'}
# group_iii.silver.initemcost {'Procurement & Inventory'}
# group_iii.silver.initemsite {'Procurement & Inventory'}
# group_iii.silver.initemstats {'Procurement & Inventory'}
# group_iii.silver.initemclassrep {'Procurement & Inventory'}
# group_iii.silver.initemcategory {'Sales'}
# group_iii.silver.initemplan {'Procurement & Inventory'}
# group_iii.silver.initemsitehistbycostcenterd {'Procurement & Inventory'}
# group_iii.silver.initemrep {'Procurement & Inventory'}
# group_iii.silver.initemsaleshist {'Procurement & Inventory'}
# group_iii.silver.initemcosthist {'Procurement & Inventory'}
# group_iii.silver.initemxref {'Procurement & Inventory'}
# group_iii.silver.initemsitehist {'Procurement & Inventory'}
# group_iii.silver.initembox {'Procurement & Inventory'}
# group_iii.silver.initemclasscurysettings {'Procurement & Inventory'}
# group_iii.silver.initemsitehistd {'Procurement & Inventory'}
# group_iii.silver.initemcustsaleshist {'Procurement & Inventory'}
# group_iii.silver.initemsaleshistd {'Procurement & Inventory'}

# %%
# phrase matching: search for documents containing your query terms as an exact phrase
# https://milvus.io/docs/phrase-match.md
# The slop parameter controls the maximum number of positions allowed between matching tokens
filter = "PHRASE_MATCH(text, 'inventory levels')"

res5 = client.query(
    collection_name=collection_name,
    filter=filter,
    output_fields=["id", "text", "name", "category"]
)

[x for x in res5]
# Out:
# [{'id': 0,
#   'text': 'table name:group_iii.silver.group_iii_purchase_xlsx_g_3_p_order\ntable description:  It covers data from various dates and contains information about purchase orders, including details such as order number, date, vendor, status, and quantities. This data is valuable for tracking purchase orders, analyzing vendor performance, and managing inventory levels.\ntable_primary_keys:OrderNbr,LineNbr\ncolumns available:Type,OrderNbr,Date,PromisedOn,Vendor,VendorName,Status,TotalOrderQty,OpenQuantity,CreatedBy,InventoryID,Description,Description_2,ShipTo,AccountName,OrderQty_2,QtyOnReceipts,ExtCost,UnitCost,LineNbr,BranchID,EntityType\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.group_iii_purchase_xlsx_g_3_p_order',
#   'category': 'Procurement & Inventory'},
#  {'id': 1,
#   'text': 'table name:group_iii.silver.initemsitehistday\ntable description:  It covers data from the years 2023 to 2025. The table contains information about inventory movements, including details such as company ID, inventory ID, site ID, location ID, and various quantity metrics. This data is valuable for tracking inventory levels, analyzing stock movements, and optimizing supply chain operations.\ntable_primary_keys:CompanyID,InventoryID,SubItemID,SiteID,LocationID,SDate\ncolumns available:CompanyID,InventoryID,SubItemID,SiteID,LocationID,SDate,BegQty,EndQty,QtyReceived,QtyIssued,QtySales,QtyCreditMemos,QtyDropShipSales,QtyTransferIn,QtyTransferOut,QtyAssemblyIn,QtyAssemblyOut,QtyAdjusted,QtyDebit,QtyCredit,tstamp\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.initemsitehistday',
#   'category': 'Procurement & Inventory'},
#  {'id': 93,
#   'text': 'table name:group_iii.silver.cropportunityproducts\ntable description:  It covers data from the current year and contains information about opportunity products, including details such as company ID, quote ID, line numbers, descriptions, and pricing details. This data is valuable for analyzing sales opportunities, tracking product performance, and managing inventory levels.\ntable_primary_keys:CompanyID,QuoteID,LineNbr\ncolumns available:CompanyID,QuoteID,LineNbr,SortOrder,GroupLineNbr,IsGroup,LineType,CuryInfoID,Descr,NoteID,CuryAmount,Amount,Quantity,BaseQuantity,InventoryID,SubItemID,UOM,TaxCategoryID,ExpenseAccountGroupID,RevenueAccountGroupID,ProjectID,TaskID,CostCodeID,EmployeeID,TaskCD,CuryExtPrice,ExtPrice,CuryExtCost,ExtCost,CuryUnitPrice,UnitPrice,CuryUnitCost,UnitCost,CustomerID,DiscountsAppliedToLine,GroupDiscountRate,DocumentDiscountRate,DiscountID,DiscountSequenceID,DiscPct,CuryDiscAmt,DiscAmt,ManualPrice,DetDiscIDC1,DetDiscSeqIDC1,DetDiscIDC2,DetDiscSeqIDC2,DetDiscApp,DocDiscIDC1,DocDiscSeqIDC1,DocDiscIDC2,DocDiscSeqIDC2,ManualDisc,SkipLineDiscounts,AutomaticDiscountsDisabled,IsFree,VendorID,POCreate,SiteID,tstamp,CreatedByID,CreatedByScreenID,CreatedDateTime,LastModifiedByID,LastModifiedByScreenID,LastModifiedDateTime,AMConfigurationID,AMParentLineNbr,AMIsSupplemental,AMConfigKeyID,BillingRule,EstimatedDuration,VendorLocationID\ncategory: Marketing',
#   'name': 'group_iii.silver.cropportunityproducts',
#   'category': 'Marketing'},
#  {'id': 145,
#   'text': 'table name:group_iii.silver.poreceiptline\ntable description:  It covers data from the years 2023 to 2025. The table contains information about purchase order receipts, including details such as company ID, receipt type, receipt number, line number, and receipt date. This data is valuable for tracking purchase order receipts, analyzing vendor performance, and managing inventory levels.\ntable_primary_keys:ReceiptNbr\ncolumns available:CompanyID,ReceiptType,ReceiptNbr,LineNbr,SortOrder,BranchID,InventoryID,AccrueCost,VendorID,ReceiptDate\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.poreceiptline',
#   'category': 'Procurement & Inventory'},
#  {'id': 164,
#   'text': 'table name:group_iii.silver.incoststatus\ntable description:  It covers data up to the year 2025. The table contains information about costs and inventory, including details such as company ID, cost ID, inventory ID, and receipt details. This data is valuable for tracking inventory costs, analyzing financial metrics, and managing inventory levels.\ntable_primary_keys:InventoryID\ncolumns available:CompanyID,CostID,InventoryID,CostSubItemID,CostSiteID,AccountID,SubID,SiteID,ReceiptNbr,ReceiptDate,LotSerialNbr,OrigQty,QtyOnHand,UnitCost,TotalCost,tstamp,ValMethod,LayerType\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.incoststatus',
#   'category': 'Procurement & Inventory'},
#  {'id': 209,
#   'text': 'table name:group_iii.silver.insitestatus\ntable description:  It covers data from the years 2023 to 2024. The table contains information about inventory and order quantities, including details such as company ID, inventory ID, site ID, and various quantity metrics. This data is valuable for tracking inventory levels, order statuses, and production planning, providing insights into supply chain efficiency and operational performance.\ntable_primary_keys:CompanyID,InventoryID,SubItemID,SiteID\ncolumns available:CompanyID,InventoryID,SubItemID,SiteID,QtyOnHand,QtyNotAvail,QtyAvail,QtyHardAvail,QtyActual,QtyInTransit,QtyInTransitToSO,QtyINReplaned,QtyPOPrepared,QtyPOOrders,QtyPOReceipts,QtyFSSrvOrdBooked,QtyFSSrvOrdAllocated,QtyFSSrvOrdPrepared,QtySOBackOrdered,QtySOPrepared,QtySOBooked,QtySOShipped,QtySOShipping,QtyFixedFSSrvOrd,QtyPOFixedFSSrvOrd,QtyPOFixedFSSrvOrdPrepared,QtyPOFixedFSSrvOrdReceipts,QtySOFixed,QtyPOFixedOrders,QtyPOFixedPrepared,QtyPOFixedReceipts,QtySODropShip,QtyPODropShipOrders,QtyPODropShipPrepared,QtyPODropShipReceipts,tstamp,QtyINIssues,QtyINReceipts,QtyINAssemblySupply,QtyINAssemblyDemand,QtyInTransitToProduction,QtyProductionSupplyPrepared,QtyProductionSupply,QtyPOFixedProductionPrepared,QtyPOFixedProductionOrders,QtyProductionDemandPrepared,QtyProductionDemand,QtyProductionAllocated,QtySOFixedProduction,QtyProdFixedPurchase,QtyProdFixedProduction,QtyProdFixedProdOrdersPrepared,QtyProdFixedProdOrders,QtyProdFixedSalesOrdersPrepared,QtyProdFixedSalesOrders,Qty,LastModifiedByScreenID,LastModifiedDateTime\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.insitestatus',
#   'category': 'Procurement & Inventory'},
#  {'id': 244,
#   'text': 'table name:group_iii.silver.soshipline\ntable description:  It covers data from the years 2023 to 2025. The table contains information about shipment lines, including details such as shipment number, type, line number, customer ID, and various quantities. This data is valuable for tracking shipments, analyzing inventory levels, and managing order fulfillment processes.\ntable_primary_keys:CompanyID,ShipmentNbr,LineNbr\ncolumns available:CompanyID,DatabaseRecordStatus,ShipmentNbr,ShipmentType,LineNbr,SortOrder,CustomerID,ShipDate,LineType,InventoryID,SubItemID,SiteID,LocationID,LotSerialNbr,InvtMult,Operation,ExpireDate,OrigOrderType,OrigOrderNbr,OrigLineNbr,OrigSplitLineNbr,OrderUOM,UOM,CompleteQtyMin,ShippedQty,BaseShippedQty,BaseOriginalShippedQty,UnassignedQty,OrigOrderQty,BaseOrigOrderQty,FullOrderQty,BaseFullOrderQty,UnitCost,ExtCost,UnitPrice,DiscPct,AlternateID,TranDesc,UnitWeigth,UnitVolume,ExtWeight,ExtVolume,ProjectID,TaskID,CostCodeID,ReasonCode,IsFree,ManualPrice,ManualDisc,DiscountsAppliedToLine,DiscountID,DiscountSequenceID,PickedQty,BasePickedQty,PackedQty,BasePackedQty,CreatedDateTime,CreatedByID,CreatedByScreenID,LastModifiedDateTime,LastModifiedByID,LastModifiedByScreenID,tstamp,Confirmed,Released,IsUnassigned,PlanType,OrigPlanType,ShipComplete,RequireINUpdate,NoteID,IsIntercompany,AssociatedOrderLineNbr,GiftMessage,BlanketType,BlanketNbr,BlanketLineNbr,BlanketSplitLineNbr,IsStockItem,SOLineSign,IsSpecialOrder,CostCenterID,UsrALGS1SGTIN,UsrALEPCTagID,UsrALPrintLabel,UsrALNbrOfCopies,UsrALLabelQty,UsrALBoxXofY,UsrIGCMIsInCont,UsrIGCMUsedInPOReceipt,UsrSSExtPrice\ncategory: Sales',
#   'name': 'group_iii.silver.soshipline',
#   'category': 'Sales'},
#  {'id': 273,
#   'text': 'table name:group_iii.silver.initemsite\ntable description:  It covers data from various inventory and site-related metrics, including identifiers, costs, and flags for overrides. The table contains information about inventory management, site status, and replenishment strategies. This data is valuable for tracking inventory levels, managing site operations, and optimizing replenishment processes.\ntable_primary_keys:CompanyID,InventoryID,SiteID\ncolumns available:CompanyID,InventoryID,SiteID,InvtAcctID,InvtSubID,OverrideInvtAcctSub,DfltSalesUnit,DfltPurchaseUnit,LastStdCost,PendingStdCostDate,PendingStdCost,PendingStdCostReset,StdCost,StdCostDate,CreatedByID,CreatedByScreenID,CreatedDateTime,LastModifiedByID,LastModifiedByScreenID,LastModifiedDateTime,tstamp,DfltShipLocationID,DfltReceiptLocationID,IsDefault,StdCostOverride,BasePriceOverride,LastBasePrice,PendingBasePriceDate,PendingBasePrice,BasePrice,BasePriceDate,ProductWorkGroupID,ProductManagerID,PriceWorkGroupID,PriceManagerID,SiteStatus,PreferredVendorOverride,PreferredVendorID,PreferredVendorLocationID,Commissionable,ValMethod,ABCCodeOverride,ABCCodeID,ABCCodeIsFixed,MovementClassOverride,MovementClassID,MovementClassIsFixed,MarkupPct,MarkupPctOverride,RecPrice,RecPriceOverride,ReplenishmentClassID,ReplenishmentMethod,ReplenishmentPolicyOverride,ReplenishmentPolicyID,ReplenishmentSource,ReplenishmentSourceSiteID,MaxShelfLifeOverride,MaxShelfLife,LaunchDateOverride,LaunchDate,TerminationDateOverride,TerminationDate,ServiceLevelOverride,ServiceLevel,SafetyStockOverride,SafetyStock,MinQtyOverride,MinQty,MaxQtyOverride,MaxQty,TransferERQOverride,TransferERQ,ESSmoothingConstantL,ESSmoothingConstantLOverride,ESSmoothingConstantT,ESSmoothingConstantTOverride,ESSmoothingConstantS,ESSmoothingConstantSOverride,AutoFitModel,LastForecastDate,ForecastModelType,ForecastPeriodType,SafetyStockSuggested,MinQtySuggested,MaxQtySuggested,DemandPerDayAverage,DemandPerDayMSE,DemandPerDayMAD,LeadTimeAverage,LeadTimeMAD,LeadTimeMSE,LastFCApplicationDate,SubItemOverride,CountryOfOrigin,NoteID,ProductManagerOverride,AMBOMID,AMPlanningBOMID,AMLotSizeOverride,AMLotSize,AMMaxOrdQtyOverride,AMMaxOrdQty,AMMinOrdQtyOverride,AMMinOrdQty,AMMFGLeadTimeOverride,AMMFGLeadTime,AMGroupWindowOverride,AMGroupWindow,AMConfigurationID,AMScrapOverride,AMScrapSiteID,AMScrapLocationID,AMTransferLeadTime,AMTransferLeadTimeOverride,PlanningMethod,AMSourceSiteID,AMSourceSiteIDOverride,AMReplenishmentSourceOverride\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.initemsite',
#   'category': 'Procurement & Inventory'},
#  {'id': 278,
#   'text': 'table name:group_iii.silver.initemstats\ntable description:  It covers data from the years 2023 to 2025. The table contains information about inventory items, including details such as CompanyID, InventoryID, SiteID, and various cost metrics. This data is valuable for tracking inventory levels, costs, and site-specific information, aiding in inventory management and financial analysis.\ntable_primary_keys:CompanyID,InventoryID,SiteID\ncolumns available:CompanyID,InventoryID,SiteID,QtyOnHand,TotalCost,MinCost,MaxCost,LastCost,LastCostDate,LastPurchaseDate,ValMethod,tstamp\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.initemstats',
#   'category': 'Procurement & Inventory'},
#  {'id': 307,
#   'text': 'table name:group_iii.silver.povendorinventory\ntable description:  It covers data from the years 2022 to 2025. The table contains information about vendor inventory, including details such as CompanyID, RecordID, VendorID, and InventoryID. This data is valuable for tracking vendor inventory levels, managing purchase orders, and analyzing vendor performance.\ntable_primary_keys:RecordID\ncolumns available:CompanyID,RecordID,VendorID,VendorLocationID,InventoryID,SubItemID,PurchaseUnit,VendorInventoryID,AddLeadTimeDays,Active,MinOrdFreq,MinOrdQty,MaxOrdQty,LotSize,ERQ,CuryID,PendingPrice,PendingDate,EffPrice,EffDate,LastPrice,OverrideSettings,PrepaymentPct,tstamp,CreatedByID,CreatedByScreenID,CreatedDateTime,LastModifiedByID,LastModifiedByScreenID,LastModifiedDateTime,NoteID\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.povendorinventory',
#   'category': 'Procurement & Inventory'},
#  {'id': 319,
#   'text': 'table name:group_iii.silver.inlocationstatusbycostcenter\ntable description:  It covers data from the current operational period and contains information about inventory and order quantities across various sites and locations. This data is valuable for tracking inventory levels, order statuses, and production planning, providing insights into supply chain efficiency and operational performance.\ntable_primary_keys:CompanyID,InventoryID,SubItemID,SiteID,LocationID,CostCenterID\ncolumns available:CompanyID,InventoryID,SubItemID,SiteID,LocationID,CostCenterID,QtyOnHand,QtyAvail,QtyHardAvail,QtyActual,QtyFSSrvOrdBooked,QtyFSSrvOrdAllocated,QtyFSSrvOrdPrepared,QtySOBackOrdered,QtySOPrepared,QtySOBooked,QtySOShipped,QtySOShipping,QtyINIssues,QtyINReceipts,QtyInTransit,QtyInTransitToSO,QtyPOReceipts,QtyPOPrepared,QtyPOOrders,QtyFixedFSSrvOrd,QtyPOFixedFSSrvOrd,QtyPOFixedFSSrvOrdPrepared,QtyPOFixedFSSrvOrdReceipts,QtySOFixed,QtyPOFixedOrders,QtyPOFixedPrepared,QtyPOFixedReceipts,QtySODropShip,QtyPODropShipOrders,QtyPODropShipPrepared,QtyPODropShipReceipts,QtyINAssemblySupply,QtyINAssemblyDemand,QtyInTransitToProduction,QtyProductionSupplyPrepared,QtyProductionSupply,QtyPOFixedProductionPrepared,QtyPOFixedProductionOrders,QtyProductionDemandPrepared,QtyProductionDemand,QtyProductionAllocated,QtySOFixedProduction,QtyProdFixedPurchase,QtyProdFixedProduction,QtyProdFixedProdOrdersPrepared,QtyProdFixedProdOrders,QtyProdFixedSalesOrdersPrepared,QtyProdFixedSalesOrders,tstamp,LastModifiedByScreenID,LastModifiedDateTime\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.inlocationstatusbycostcenter',
#   'category': 'Procurement & Inventory'},
#  {'id': 334,
#   'text': 'table name:group_iii.silver.initemsitehistbycostcenterd\ntable description:  It covers data from the years 2023 to 2025. The table contains information about inventory movements and costs across different sites and cost centers, including details such as quantities, costs, and timestamps of transactions. This data is valuable for tracking inventory levels, analyzing cost fluctuations, and optimizing resource allocation across sites.\ntable_primary_keys:CompanyID\ncolumns available:CompanyID,SiteID,InventoryID,SubItemID,CostCenterID,SDate,SYear,SMonth,SQuater,SDay,SDayOfWeek,tstamp,BegQty,EndQty,QtyDebit,QtyCredit,QtyReceived,QtyIssued,QtySales,QtyCreditMemos,QtyDropShipSales,QtyTransferIn,QtyTransferOut,QtyAssemblyIn,QtyAssemblyOut,QtyAdjusted,CostDebit,CostCredit,LastModifiedByScreenID,LastModifiedDateTime,EndCost\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.initemsitehistbycostcenterd',
#   'category': 'Procurement & Inventory'},
#  {'id': 364,
#   'text': 'table name:group_iii.silver.inpidetail\ntable description:  It covers data from the year 2023 to 2024. The table contains detailed information about physical inventory, including identifiers, quantities, costs, and timestamps. This data is valuable for tracking inventory levels, managing stock, and analyzing cost variances.\ntable_primary_keys:CompanyID,PIID,LineNbr\ncolumns available:CompanyID,PIID,LineNbr,InventoryID,SubItemID,SiteID,LocationID,LotSerialNbr,ExpireDate,TagNumber,BookQty,PhysicalQty,VarQty,UnitCost,ExtBookCost,ExtVarCost,FinalExtVarCost,Status,ReasonCode,CreatedByID,CreatedByScreenID,CreatedDateTime,LastModifiedByID,LastModifiedByScreenID,LastModifiedDateTime,tstamp,LineType,NoteID,ManualCost\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.inpidetail',
#   'category': 'Procurement & Inventory'},
#  {'id': 418,
#   'text': 'table name:group_iii.silver.ispssolineextension\ntable description:  It covers data from various orders and line items, including details such as order number, order type, line number, and pricing information. This data is valuable for tracking order details, analyzing pricing strategies, and managing inventory levels.\ntable_primary_keys:OrderNbr\ncolumns available:CompanyID,OrderNbr,OrderType,LineNbr,ISPSEdiLine,ISPSTPLineNbr,ISPSOrderQtyUDF,ISPSOrderQtyUOM,ISPSEDIPrice,ISPSRetailPrice,ISPSInnerPackValue,ISPSOuterPackValue,ISPSPackSize,ISPSLineAckStatus1,ISPSLineAckStatus2,ISPSLineAckQty1,ISPSLineAckQty2,ISPSLineAckDate1,ISPSLineAckDate2,ISPSReasonCode,ISPSVendorPartNo,ISPSBuyerPartNo,ISPSConsumerPckgCode,ISPSUPCCaseCode,ISPSPOLineNbr,ISPSLineUDF1,ISPSLineUDF2,ISPSLineUDF3,ISPSLineUDF4,ISPSLineUDF5,ISPSLineUDF6,ISPSLineUDF7,ISPSLineUDF8,ISPSLineUDF9,ISPSLineUDF10,ISPSLineUDF11,ISPSLineUDF12,ISPSLineUDF13,ISPSLineUDF14,ISPSLineUDF15,ISPSLineUDF16,ISPSLineUDF17,ISPSLineUDF18,ISPSLineUDF19,ISPSLineUDF20\ncategory: Process Management',
#   'name': 'group_iii.silver.ispssolineextension',
#   'category': 'Process Management'},
#  {'id': 421,
#   'text': 'table name:group_iii.silver.initemrep\ntable description:  It covers data from the years 2022 to 2023. The table contains information about inventory replenishment, including details such as company ID, inventory ID, replenishment class, policy, method, and source. It also tracks creation and modification timestamps along with user IDs. This data is valuable for managing inventory levels, optimizing replenishment strategies, and tracking changes over time.\ntable_primary_keys:CompanyID,InventoryID\ncolumns available:CompanyID,ReplenishmentClassID,InventoryID,CuryID,ReplenishmentPolicyID,ReplenishmentMethod,ReplenishmentSource,ReplenishmentSourceSiteID,MaxShelfLife,LaunchDate,TerminationDate,ServiceLevel,SafetyStock,MinQty,MaxQty,TransferERQ,ForecastModelType,ForecastPeriodType,HistoryDepth,ESSmoothingConstantL,ESSmoothingConstantT,ESSmoothingConstantS,AutoFitModel,CreatedByID,CreatedByScreenID,CreatedDateTime,LastModifiedByID,LastModifiedByScreenID,LastModifiedDateTime,tstamp\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.initemrep',
#   'category': 'Procurement & Inventory'},
#  {'id': 429,
#   'text': 'table name:group_iii.silver.inunit\ntable description:  It covers data related to unit conversions and inventory management. The table includes columns such as CompanyID, UnitType, InventoryID, and RecordID, which are crucial for identifying and managing inventory items. This data is valuable for tracking inventory levels, managing unit conversions, and ensuring accurate inventory records.\ntable_primary_keys:RecordID\ncolumns available:CompanyID,UnitType,ItemClassID,InventoryID,FromUnit,ToUnit,UnitMultDiv,UnitRate,PriceAdjustmentMultiplier,RecordID,CreatedByID,CreatedByScreenID,CreatedDateTime,LastModifiedByID,LastModifiedByScreenID,LastModifiedDateTime,tstamp,CompanyMask,UsrALGS1PackagingLevel,UsrALEPCSGTINFilterValue\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.inunit',
#   'category': 'Procurement & Inventory'},
#  {'id': 495,
#   'text': "table name:group_iii.silver.insitestatusbycostcenter\ntable description:  It covers data from the current operational period and contains information about inventory and order statuses by cost center. Key columns include 'CompanyID', 'InventoryID', 'SiteID', and 'CostCenterID'. This data is valuable for tracking inventory levels, order statuses, and operational metrics across different cost centers, aiding in resource allocation and operational efficiency analysis.\ntable_primary_keys:CompanyID,InventoryID,SiteID,CostCenterID\ncolumns available:CompanyID,InventoryID,SubItemID,SiteID,CostCenterID,QtyOnHand,QtyNotAvail,QtyAvail,QtyHardAvail,QtyActual,QtyInTransit,QtyInTransitToSO,QtyINReplaned,QtyPOPrepared,QtyPOOrders,QtyPOReceipts,QtyFSSrvOrdBooked,QtyFSSrvOrdAllocated,QtyFSSrvOrdPrepared,QtySOBackOrdered,QtySOPrepared,QtySOBooked,QtySOShipped,QtySOShipping,QtyFixedFSSrvOrd,QtyPOFixedFSSrvOrd,QtyPOFixedFSSrvOrdPrepared,QtyPOFixedFSSrvOrdReceipts,QtySOFixed,QtyPOFixedOrders,QtyPOFixedPrepared,QtyPOFixedReceipts,QtySODropShip,QtyPODropShipOrders,QtyPODropShipPrepared,QtyPODropShipReceipts,QtyINIssues,QtyINReceipts,QtyINAssemblySupply,QtyINAssemblyDemand,QtyInTransitToProduction,QtyProductionSupplyPrepared,QtyProductionSupply,QtyPOFixedProductionPrepared,QtyPOFixedProductionOrders,QtyProductionDemandPrepared,QtyProductionDemand,QtyProductionAllocated,QtySOFixedProduction,QtyProdFixedPurchase,QtyProdFixedProduction,QtyProdFixedProdOrdersPrepared,QtyProdFixedProdOrders,QtyProdFixedSalesOrdersPrepared,QtyProdFixedSalesOrders,tstamp,LastModifiedByScreenID,LastModifiedDateTime\ncategory: Procurement & Inventory",
#   'name': 'group_iii.silver.insitestatusbycostcenter',
#   'category': 'Procurement & Inventory'},
#  {'id': 538,
#   'text': 'table name:group_iii.silver.inventory_asin_sourcing_retail_united_states_todate_1_1_2025_4_6_2025\ntable description:  It covers data from January 1, 2025, to April 6, 2025. The table contains information about inventory sourcing in the United States, including details such as ASIN, product title, brand, category, and various inventory metrics. This data is valuable for analyzing inventory levels, vendor performance, and sales trends to optimize sourcing strategies and improve supply chain efficiency.\ntable_primary_keys:ASIN\ncolumns available:ASIN,Product Title,Brand,Category,Subcategory,Parent ASIN,UPC,Model Number,Child Vendor Code,Color,Vendor Confirmation Rate,Vendor Confirmation Rate - Same Period Last Year (bps),Net Received,Net Received - Same Period Last Year (%),Net Received Units,Net Received Units - Same Period Last Year (%),Open Purchase Order Quantity,Open Purchase Order Quantity - Same Period Last Year (%),Receive Fill Rate %,Receive Fill Rate % - Same Period Last Year (bps),Overall Vendor Lead Time (days),Overall Vendor Lead Time (days) - Same Period Last Year (%),Aged 90+ Days Sellable Inventory,Aged 90+ Days Sellable Inventory - Same Period Last Year (%),Aged 90+ Days Sellable Units,Aged 90+ Days Sellable Units - Same Period Last Year (%),Sellable On Hand Inventory,Sellable On Hand Inventory - Same Period Last Year (%),Sellable On Hand Units,Sellable On Hand Units - Same Period Last Year (%),Unsellable On Hand Inventory,Unsellable On Hand Inventory - Same Period Last Year (%),Unsellable On Hand Units,Unsellable On Hand Units - Same Period Last Year (%),Sell-Through Rate,Sell-Through Rate - Same Period Last Year (bps),Unhealthy Inventory,Unhealthy Inventory - Same Period Last Year (%),Unhealthy Units,Unhealthy Units - Same Period Last Year (%),Confirmed Units,Confirmed Units - Same Period Last Year (%),Sales Discount,Sales Discount - Same Period Last Year (%),Contra-COGS,Contra-COGS - Same Period Last Year (%),In Transit Quantity,In Transit Quantity - Same Period Last Year (%),Sellable In Transit Units,Sellable In Transit Units - Same Period Last Year (%),Unsellable In Transit Units,Unsellable In Transit Units - Same Period Last Year (%)\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.inventory_asin_sourcing_retail_united_states_todate_1_1_2025_4_6_2025',
#   'category': 'Procurement & Inventory'},
#  {'id': 578,
#   'text': 'table name:group_iii.silver.initembox\ntable description:  It contains data related to inventory items, including identifiers, quantities, and timestamps. The table is useful for tracking inventory levels and changes over time.\ntable_primary_keys:CompanyID,InventoryID\ncolumns available:CompanyID,InventoryID,BoxID,Qty,UOM,BaseQty,CreatedByID,CreatedByScreenID,CreatedDateTime,LastModifiedByID,LastModifiedByScreenID,LastModifiedDateTime,tstamp,NoteID,UsrALGS1PackagingLevel,UsrALEPCSGTINFilterValue,UsrALGS1GenerateSSCC,UsrALEPCSSCCFilterValue\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.initembox',
#   'category': 'Procurement & Inventory'},
#  {'id': 580,
#   'text': 'table name:group_iii.silver.inventory_asin_sourcing_retail_united_states_yearly_1_1_2023_12_31_2023\ntable description:  It covers data for the year 2023. The table contains information about product inventory, including details such as ASIN, product title, brand, category, and various inventory metrics. This data is valuable for analyzing inventory levels, vendor performance, and sales trends to optimize sourcing and retail strategies.\ntable_primary_keys:ASIN\ncolumns available:ASIN,Product Title,Brand,Category,Subcategory,Parent ASIN,UPC,Model Number,Child Vendor Code,Color,Vendor Confirmation Rate,Vendor Confirmation Rate - Same Period Last Year (bps),Net Received,Net Received - Same Period Last Year (%),Net Received Units,Net Received Units - Same Period Last Year (%),Open Purchase Order Quantity,Open Purchase Order Quantity - Same Period Last Year (%),Receive Fill Rate %,Receive Fill Rate % - Same Period Last Year (bps),Overall Vendor Lead Time (days),Overall Vendor Lead Time (days) - Same Period Last Year (%),Aged 90+ Days Sellable Inventory,Aged 90+ Days Sellable Inventory - Same Period Last Year (%),Aged 90+ Days Sellable Units,Aged 90+ Days Sellable Units - Same Period Last Year (%),Sellable On Hand Inventory,Sellable On Hand Inventory - Same Period Last Year (%),Sellable On Hand Units,Sellable On Hand Units - Same Period Last Year (%),Unsellable On Hand Inventory,Unsellable On Hand Inventory - Same Period Last Year (%),Unsellable On Hand Units,Unsellable On Hand Units - Same Period Last Year (%),Sell-Through Rate,Sell-Through Rate - Same Period Last Year (bps),Unhealthy Inventory,Unhealthy Inventory - Same Period Last Year (%),Unhealthy Units,Unhealthy Units - Same Period Last Year (%),Confirmed Units,Confirmed Units - Same Period Last Year (%),Sales Discount,Sales Discount - Same Period Last Year (%),Contra-COGS,Contra-COGS - Same Period Last Year (%),In Transit Quantity,In Transit Quantity - Same Period Last Year (%),Sellable In Transit Units,Sellable In Transit Units - Same Period Last Year (%),Unsellable In Transit Units,Unsellable In Transit Units - Same Period Last Year (%)\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.inventory_asin_sourcing_retail_united_states_yearly_1_1_2023_12_31_2023',
#   'category': 'Procurement & Inventory'},
#  {'id': 687,
#   'text': 'table name:group_iii.silver.igcmpolandedcostline\ntable description:  It covers data from the current period and contains information about landed costs, purchase orders, inventory, and related financial metrics. This data is valuable for tracking and managing landed costs, inventory levels, and financial allocations, providing insights into cost management and operational efficiency.\ntable_primary_keys:InventoryID,VendorID\ncolumns available:CompanyID,LandedCostNbr,LineNbr,PONbr,POOrderType,POLineNbr,InventoryID,SubItemID,LineType,SiteID,LocationID,LotSerialNbr,InvtMult,BaseQty,Qty,OpenQty,ProjectID,TaskID,OrigPlanType,UnassignedQty,SortOrder,UOM,Size,SupplierInvoiceNbr,ContainerQty,ReceiptQty,InTransitQty,DollarsAllocated,UnitCost,NoneCuryUnitCost,UnitWeight,TallyQty,LotSerialID,BranchID,UnitVolume,ExtWeight,ExtVolume,OrderQty,Descr,NoteID,ExpireDate,CuryExtCost,ExtCost,CuryDiscAmt,DiscAmt,CustomClassificationNbr,DutyAmt,Tariff,DiscPct,ContainerNbr,BaseShippedQty,CreatedByID,LastModifiedByID,CreatedByScreenID,LastModifiedByScreenID,LastModifiedDateTime,CreatedDateTime,tstamp,QtyOnContainers,VendorID,ItemLotSerTrack,GSPEligible,FactoryReadyDate,UsrIGCMInvoiceNbr,POOrderDesc,IsFromSOTransfer,DestSiteID,ShipmentNbr,UPCCode,InTransitWerhause,IsReturned,ReceiptNbr,ReceiptType,ReceiptLineNbr,ReturnQty,ReturnNbr,CostCenterID,Cancelled,CuryInfoID,APBillRefNbr,APBillNbr,VendorRefNbr,UsrIGIDCountryCode,UsrIGTBInvoiceNbr\ncategory: IT',
#   'name': 'group_iii.silver.igcmpolandedcostline',
#   'category': 'IT'},
#  {'id': 699,
#   'text': 'table name:group_iii.silver.inventory_asin_sourcing_retail_united_states_yearly_1_1_2024_12_31_2024\ntable description:  It covers data for the year 2024. The table contains information about inventory sourcing in the United States, including details such as ASIN, product title, brand, category, and various inventory metrics. This data is valuable for analyzing inventory levels, vendor performance, and sales trends to optimize sourcing strategies and improve supply chain efficiency.\ntable_primary_keys:ASIN\ncolumns available:ASIN,Product Title,Brand,Category,Subcategory,Parent ASIN,UPC,Model Number,Child Vendor Code,Color,Vendor Confirmation Rate,Vendor Confirmation Rate - Same Period Last Year (bps),Net Received,Net Received - Same Period Last Year (%),Net Received Units,Net Received Units - Same Period Last Year (%),Open Purchase Order Quantity,Open Purchase Order Quantity - Same Period Last Year (%),Receive Fill Rate %,Receive Fill Rate % - Same Period Last Year (bps),Overall Vendor Lead Time (days),Overall Vendor Lead Time (days) - Same Period Last Year (%),Aged 90+ Days Sellable Inventory,Aged 90+ Days Sellable Inventory - Same Period Last Year (%),Aged 90+ Days Sellable Units,Aged 90+ Days Sellable Units - Same Period Last Year (%),Sellable On Hand Inventory,Sellable On Hand Inventory - Same Period Last Year (%),Sellable On Hand Units,Sellable On Hand Units - Same Period Last Year (%),Unsellable On Hand Inventory,Unsellable On Hand Inventory - Same Period Last Year (%),Unsellable On Hand Units,Unsellable On Hand Units - Same Period Last Year (%),Sell-Through Rate,Sell-Through Rate - Same Period Last Year (bps),Unhealthy Inventory,Unhealthy Inventory - Same Period Last Year (%),Unhealthy Units,Unhealthy Units - Same Period Last Year (%),Confirmed Units,Confirmed Units - Same Period Last Year (%),Sales Discount,Sales Discount - Same Period Last Year (%),Contra-COGS,Contra-COGS - Same Period Last Year (%),In Transit Quantity,In Transit Quantity - Same Period Last Year (%),Sellable In Transit Units,Sellable In Transit Units - Same Period Last Year (%),Unsellable In Transit Units,Unsellable In Transit Units - Same Period Last Year (%)\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.inventory_asin_sourcing_retail_united_states_yearly_1_1_2024_12_31_2024',
#   'category': 'Procurement & Inventory'},
#  {'id': 733,
#   'text': 'table name:group_iii.silver.poorder\ntable description:  It covers data from various orders, including details such as company ID, order type, order number, vendor ID, and order totals. This data is valuable for tracking purchase orders, analyzing vendor performance, and managing inventory levels.\ntable_primary_keys:OrderNbr\ncolumns available:CompanyID,OrderType,OrderNbr,Behavior,BranchID,VendorID,VendorLocationID,OrderDate,Hold,CuryID,CuryInfoID,LineCntr,LinesToCloseCntr,LinesToCompleteCntr,VendorRefNbr,CuryOrderTotal,OrderTotal,OrderQty,CuryLineTotal,LineTotal,DiscTot,CuryDiscTot,CuryTaxTotal,TaxTotal,TaxZoneID,TaxCalcMode,TermsID,RemitAddressID,RemitContactID,ShipAddressID,ShipContactID,SiteID,BLType,BLOrderNbr,RQReqNbr,CreatedByID,CreatedByScreenID,CreatedDateTime,LastModifiedByID,LastModifiedByScreenID,LastModifiedDateTime,tstamp,Cancelled,CuryControlTotal,ControlTotal,ShipDestType,ShipToBAccountID,ShipToLocationID,OrderDesc,OpenOrderQty,CuryUnbilledOrderTotal,UnbilledOrderTotal,CuryUnbilledLineTotal,UnbilledLineTotal,CuryUnbilledTaxTotal,UnbilledTaxTotal,UnbilledOrderQty,ShipVia,FOBPoint,OwnerWorkGroupID,Status,ExpectedDate,ExpirationDate,DontPrint,Printed,DontEmail,Emailed,IsTaxValid,IsUnbilledTaxValid,LockCommitment,Approved,OrderWeight,OrderVolume,soordertype,soordernbr,VatTaxableTotal,CuryVatTaxableTotal,VatExemptTotal,CuryVatExemptTotal,NoteID,RetainageApply,DefRetainagePct,CuryLineRetainageTotal,LineRetainageTotal,CuryRetainedTaxTotal,RetainedTaxTotal,CuryRetainedDiscTotal,RetainedDiscTotal,CuryRetainageTotal,RetainageTotal,CuryPrepaidTotal,PrepaidTotal,CuryUnprepaidTotal,UnprepaidTotal,ProjectID,PayToVendorID,PrepaymentPct,DisableAutomaticDiscountCalculation,IsIntercompany,IsIntercompanySOCreated,ExcludeFromIntercompanyProc,IsLegacyDropShip,DropShipLinesCount,DropShipLinkedLinesCount,DropShipActiveLinksCount,DropShipOpenLinesCntr,DropShipNotLinkedLinesCntr,DropshipReceiptProcessing,DropshipExpenseRecording,OriginalPOType,OriginalPONbr,SpecialLineCntr,OwnerID,CuryGoodsExtCostTotal,GoodsExtCostTotal,CuryServiceExtCostTotal,ServiceExtCostTotal,CuryFreightTot,FreightTot,CuryLineDiscTotal,LineDiscTotal,CuryGroupDiscTotal,GroupDiscTotal,CuryDocumentDiscTotal,DocumentDiscTotal,OrderBasedAPBill\ncategory: Procurement & Inventory',
#   'name': 'group_iii.silver.poorder',
#   'category': 'Procurement & Inventory'}]
